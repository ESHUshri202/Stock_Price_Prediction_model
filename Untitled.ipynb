# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt

# %%
# !pip install yfinance
# Out:
# Requirement already satisfied: yfinance in c:\users\red devil\anaconda3.4\lib\site-packages (0.2.48)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\red devil\anaconda3.4\lib\site-packages (from yfinance) (1.23.5)
# Requirement already satisfied: requests>=2.31 in c:\users\red devil\anaconda3.4\lib\site-packages (from yfinance) (2.32.3)
# Requirement already satisfied: platformdirs>=2.0.0 in c:\users\red devil\anaconda3.4\lib\site-packages (from yfinance) (2.5.2)
# Requirement already satisfied: lxml>=4.9.1 in c:\users\red devil\anaconda3.4\lib\site-packages (from yfinance) (4.9.1)
# Requirement already satisfied: peewee>=3.16.2 in c:\users\red devil\anaconda3.4\lib\site-packages (from yfinance) (3.17.7)
# Requirement already satisfied: pandas>=1.3.0 in c:\users\red devil\anaconda3.4\lib\site-packages (from yfinance) (1.5.3)
# Requirement already satisfied: pytz>=2022.5 in c:\users\red devil\anaconda3.4\lib\site-packages (from yfinance) (2022.7)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\users\red devil\anaconda3.4\lib\site-packages (from yfinance) (4.11.1)
# Requirement already satisfied: html5lib>=1.1 in c:\users\red devil\anaconda3.4\lib\site-packages (from yfinance) (1.1)
# Requirement already satisfied: frozendict>=2.3.4 in c:\users\red devil\anaconda3.4\lib\site-packages (from yfinance) (2.4.6)
# Requirement already satisfied: multitasking>=0.0.7 in c:\users\red devil\anaconda3.4\lib\site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: soupsieve>1.2 in c:\users\red devil\anaconda3.4\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.3.2.post1)
# Requirement already satisfied: six>=1.9 in c:\users\red devil\anaconda3.4\lib\site-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: webencodings in c:\users\red devil\anaconda3.4\lib\site-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\red devil\anaconda3.4\lib\site-packages (from pandas>=1.3.0->yfinance) (2.8.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\red devil\anaconda3.4\lib\site-packages (from requests>=2.31->yfinance) (3.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\red devil\anaconda3.4\lib\site-packages (from requests>=2.31->yfinance) (2.0.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\red devil\anaconda3.4\lib\site-packages (from requests>=2.31->yfinance) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\red devil\anaconda3.4\lib\site-packages (from requests>=2.31->yfinance) (2024.2.2)

# %%
import yfinance as yf

# %%
start = '2012-01-01'
end = '2024-11-07'
stock = 'GOOG'

data = yf.download(stock,start,end)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
data.reset_index(inplace = True)

# %%
data
# Out:
# Price                       Date   Adj Close       Close        High  \
# Ticker                                  GOOG        GOOG        GOOG
# 0      2012-01-03 00:00:00+00:00   16.532528   16.573130   16.641375
# 1      2012-01-04 00:00:00+00:00   16.603836   16.644611   16.693678
# 2      2012-01-05 00:00:00+00:00   16.373516   16.413727   16.537264
# 3      2012-01-06 00:00:00+00:00   16.150156   16.189817   16.438385
# 4      2012-01-09 00:00:00+00:00   15.465409   15.503389   16.114599
# ...                          ...         ...         ...         ...
# 3228   2024-10-31 00:00:00+00:00  172.690002  172.690002  178.419998
# 3229   2024-11-01 00:00:00+00:00  172.649994  172.649994  173.820007
# 3230   2024-11-04 00:00:00+00:00  170.679993  170.679993  171.919998
# 3231   2024-11-05 00:00:00+00:00  171.410004  171.410004  172.097000
# 3232   2024-11-06 00:00:00+00:00  178.330002  178.330002  178.639999
#
# Price          Low        Open     Volume
# Ticker        GOOG        GOOG       GOOG
# 0        16.248346   16.262545  147611217
# 1        16.453827   16.563665  114989399
# 2        16.344486   16.491436  131808205
# 3        16.184088   16.417213  108119746
# 4        15.472754   16.102144  233776981
# ...            ...         ...        ...
# 3228    172.559998  174.720001   32801900
# 3229    170.309998  171.539993   21752900
# 3230    169.485001  171.240005   16194000
# 3231    170.369995  170.830002   12518300
# 3232    175.039993  175.350006   27061500
#
# [3233 rows x 7 columns]

# %%
ma_100_days = data.Close.rolling(100).mean()

# %%
plt.figure(figsize =(8,6))
plt.plot(ma_100_days,'r')
plt.plot(data.Close,'g')
plt.show()

# %%
ma_200_days = data.Close.rolling(200).mean()

# %%
plt.figure(figsize =(8,6))
plt.plot(ma_100_days,'r')
plt.plot(ma_200_days,'b')
plt.plot(data.Close,'g')
plt.show()

# %%
data.dropna(inplace = True)

# %%
data.isnull().sum()
# Out:
# Price      Ticker
# Date                 0
# Adj Close  GOOG      0
# Close      GOOG      0
# High       GOOG      0
# Low        GOOG      0
# Open       GOOG      0
# Volume     GOOG      0
# dtype: int64

# %%
data_train = pd.DataFrame(data.Close[0:int(len(data)*0.80)])
data_test = pd.DataFrame(data.Close[int(len(data)*0.80):len(data)])

# %%
data_train.shape
# Out:
# (2586, 1)

# %%
data_test.shape
# Out:
# (647, 1)

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler(feature_range = (0,1))

# %%
data_train_scale = scaler.fit_transform(data_train)

# %%
x = []
y = []

for i in range(100,data_train_scale.shape[0]):
    x.append(data_train_scale[i-100:i])
    y.append(data_train_scale[i,0])

# %%
from keras.layers import Dense, Dropout, LSTM
from keras.models import Sequential
# Out:
# WARNING:tensorflow:From C:\Users\Red Devil\anaconda3.4\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
x,y = np.array(x), np.array(y)

# %%
model = Sequential()
model.add(LSTM(units = 50, activation = 'relu', return_sequences = True,
              input_shape = ((x.shape[1],1))))

model.add(Dropout(0,2))
model.add(LSTM(units = 60, activation = 'relu',return_sequences = True))
model.add(Dropout(0.3))
model.add(LSTM(units= 80, activation = 'relu',return_sequences = True))
model.add(Dropout(0.4))

model.add(LSTM(units = 120,activation = 'relu'))
model.add(Dropout(0.5))
model.add(Dense(units = 1))
# Out:
# WARNING:tensorflow:From C:\Users\Red Devil\anaconda3.4\lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.

# %%
model.compile(optimizer = 'adam',loss = 'mean_squared_error')
# Out:
# WARNING:tensorflow:From C:\Users\Red Devil\anaconda3.4\lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
model.fit(x,y,epochs=50,batch_size =32, verbose = 1)
# Out:
# Epoch 1/50
# WARNING:tensorflow:From C:\Users\Red Devil\anaconda3.4\lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# 78/78 [==============================] - 35s 326ms/step - loss: 0.0243
# Epoch 2/50
# 78/78 [==============================] - 26s 330ms/step - loss: 0.0047
# Epoch 3/50
# 78/78 [==============================] - 18s 232ms/step - loss: 0.0049
# Epoch 4/50
# 78/78 [==============================] - 18s 226ms/step - loss: 0.0037
# Epoch 5/50
# 78/78 [==============================] - 20s 251ms/step - loss: 0.0036
# Epoch 6/50
# 78/78 [==============================] - 19s 247ms/step - loss: 0.0038
# Epoch 7/50
# 78/78 [==============================] - 19s 242ms/step - loss: 0.0030
# Epoch 8/50
# 78/78 [==============================] - 18s 237ms/step - loss: 0.0030
# Epoch 9/50
# 78/78 [==============================] - 19s 246ms/step - loss: 0.0028
# Epoch 10/50
# 78/78 [==============================] - 18s 235ms/step - loss: 0.0033
# Epoch 11/50
# 78/78 [==============================] - 19s 238ms/step - loss: 0.0029
# Epoch 12/50
# 78/78 [==============================] - 19s 239ms/step - loss: 0.0025
# Epoch 13/50
# 78/78 [==============================] - 19s 250ms/step - loss: 0.0025
# Epoch 14/50
# 78/78 [==============================] - 19s 246ms/step - loss: 0.0026
# Epoch 15/50
# 78/78 [==============================] - 19s 244ms/step - loss: 0.0022
# Epoch 16/50
# 78/78 [==============================] - 20s 254ms/step - loss: 0.0023
# Epoch 17/50
# 78/78 [==============================] - 19s 240ms/step - loss: 0.0022
# Epoch 18/50
# 78/78 [==============================] - 18s 233ms/step - loss: 0.0021
# Epoch 19/50
# 78/78 [==============================] - 18s 235ms/step - loss: 0.0021
# Epoch 20/50
# 78/78 [==============================] - 18s 233ms/step - loss: 0.0022
# Epoch 21/50
# 78/78 [==============================] - 18s 236ms/step - loss: 0.0020
# Epoch 22/50
# 78/78 [==============================] - 18s 235ms/step - loss: 0.0023
# Epoch 23/50
# 78/78 [==============================] - 19s 243ms/step - loss: 0.0019
# Epoch 24/50
# 78/78 [==============================] - 24s 301ms/step - loss: 0.0021
# Epoch 25/50
# 78/78 [==============================] - 22s 280ms/step - loss: 0.0021
# Epoch 26/50
# 78/78 [==============================] - 19s 244ms/step - loss: 0.0020
# Epoch 27/50
# 78/78 [==============================] - 18s 236ms/step - loss: 0.0020
# Epoch 28/50
# 78/78 [==============================] - 18s 236ms/step - loss: 0.0018
# Epoch 29/50
# 78/78 [==============================] - 18s 234ms/step - loss: 0.0018
# Epoch 30/50
# 78/78 [==============================] - 18s 236ms/step - loss: 0.0019
# Epoch 31/50
# 78/78 [==============================] - 18s 235ms/step - loss: 0.0016
# Epoch 32/50
# 78/78 [==============================] - 18s 236ms/step - loss: 0.0018
# Epoch 33/50
# 78/78 [==============================] - 19s 239ms/step - loss: 0.0016
# Epoch 34/50
# 78/78 [==============================] - 18s 234ms/step - loss: 0.0017
# Epoch 35/50
# 78/78 [==============================] - 18s 236ms/step - loss: 0.0019
# Epoch 36/50
# 78/78 [==============================] - 19s 242ms/step - loss: 0.0017
# Epoch 37/50
# 78/78 [==============================] - 19s 239ms/step - loss: 0.0017
# Epoch 38/50
# 78/78 [==============================] - 18s 236ms/step - loss: 0.0015
# Epoch 39/50
# 78/78 [==============================] - 18s 235ms/step - loss: 0.0018
# Epoch 40/50
# 78/78 [==============================] - 18s 234ms/step - loss: 0.0017
# Epoch 41/50
# 78/78 [==============================] - 19s 238ms/step - loss: 0.0019
# Epoch 42/50
# 78/78 [==============================] - 18s 236ms/step - loss: 0.0016
# Epoch 43/50
# 78/78 [==============================] - 19s 249ms/step - loss: 0.0018
# Epoch 44/50
# 78/78 [==============================] - 20s 262ms/step - loss: 0.0016
# Epoch 45/50
# 78/78 [==============================] - 20s 252ms/step - loss: 0.0017
# Epoch 46/50
# 78/78 [==============================] - 19s 244ms/step - loss: 0.0018
# Epoch 47/50
# 78/78 [==============================] - 18s 235ms/step - loss: 0.0018
# Epoch 48/50
# 78/78 [==============================] - 18s 236ms/step - loss: 0.0016
# Epoch 49/50
# 78/78 [==============================] - 18s 236ms/step - loss: 0.0015
# Epoch 50/50
# 78/78 [==============================] - 18s 236ms/step - loss: 0.0017

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 100, 50)           10400
#
#  dropout (Dropout)           (None, 100, 50)           0
#
#  lstm_1 (LSTM)               (None, 100, 60)           26640
#
#  dropout_1 (Dropout)         (None, 100, 60)           0
#
#  lstm_2 (LSTM)               (None, 100, 80)           45120
#
#  dropout_2 (Dropout)         (None, 100, 80)           0
#
#  lstm_3 (LSTM)               (None, 120)               96480
#
#  dropout_3 (Dropout)         (None, 120)               0
#
#  dense (Dense)               (None, 1)                 121
#
# =================================================================
# Total params: 178761 (698.29 KB)
# Trainable params: 178761 (698.29 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
pas_100_days = data_train.tail(100)

# %%
data_test = pd.concat([pas_100_days,data_test],ignore_index = True)

# %%
data_test_scale = scaler.fit_transform(data_test)

# %%
x = []
y = []

for i in range(100,data_test_scale.shape[0]):
    x.append(data_test_scale[i-100:i])
    y.append(data_test_scale[i,0])

# %%
x,y =np.array(x),np.array(y)

# %%
y_predict = model.predict(x)
# Out:
# 21/21 [==============================] - 3s 85ms/step

# %%
y_predict
# Out:
# array([[0.52061725],
#        [0.51173663],
#        [0.49915707],
#        [0.48392898],
#        [0.4676096 ],
#        [0.4522338 ],
#        [0.43878013],
#        [0.42692602],
#        [0.41503382],
#        [0.40296155],
#        [0.3906716 ],
#        [0.37792304],
#        [0.3652432 ],
#        [0.3531028 ],
#        [0.34182984],
#        [0.33176723],
#        [0.3236401 ],
#        [0.3172139 ],
#        [0.31204703],
#        [0.3076232 ],
#        [0.3035793 ],
#        [0.2996894 ],
#        [0.2959814 ],
#        [0.2926267 ],
#        [0.28969172],
#        [0.28727207],
#        [0.2851731 ],
#        [0.28310096],
#        [0.28069103],
#        [0.2779707 ],
#        [0.27501696],
#        [0.27210075],
#        [0.26921588],
#        [0.26657617],
#        [0.26427406],
#        [0.26237622],
#        [0.26105407],
#        [0.26030877],
#        [0.2601374 ],
#        [0.26058942],
#        [0.26161218],
#        [0.26316032],
#        [0.26481345],
#        [0.2660457 ],
#        [0.2664873 ],
#        [0.26624468],
#        [0.26544404],
#        [0.26418182],
#        [0.2627427 ],
#        [0.26127857],
#        [0.25990045],
#        [0.25888488],
#        [0.25839102],
#        [0.2583321 ],
#        [0.2585266 ],
#        [0.25876144],
#        [0.2588693 ],
#        [0.25886458],
#        [0.25886324],
#        [0.25911853],
#        [0.25985926],
#        [0.2611052 ],
#        [0.26283056],
#        [0.26466423],
#        [0.26628047],
#        [0.2673972 ],
#        [0.26780394],
#        [0.26770797],
#        [0.2673697 ],
#        [0.2670109 ],
#        [0.26651686],
#        [0.26576352],
#        [0.2646653 ],
#        [0.26341063],
#        [0.26219442],
#        [0.26124105],
#        [0.26065186],
#        [0.26050127],
#        [0.260906  ],
#        [0.26195067],
#        [0.26372588],
#        [0.26621118],
#        [0.2691804 ],
#        [0.27247098],
#        [0.2759948 ],
#        [0.27986756],
#        [0.28438565],
#        [0.28968716],
#        [0.295235  ],
#        [0.30063477],
#        [0.30515245],
#        [0.3078401 ],
#        [0.30846503],
#        [0.30727112],
#        [0.30492762],
#        [0.30156434],
#        [0.29752198],
#        [0.29304698],
#        [0.2881927 ],
#        [0.28317252],
#        [0.2784681 ],
#        [0.27430254],
#        [0.27060977],
#        [0.26743218],
#        [0.26468116],
#        [0.26230404],
#        [0.26018116],
#        [0.25825784],
#        [0.25639245],
#        [0.25435925],
#        [0.25202063],
#        [0.2492172 ],
#        [0.24584576],
#        [0.24188255],
#        [0.23736253],
#        [0.23238967],
#        [0.22704266],
#        [0.22162472],
#        [0.21627952],
#        [0.2110243 ],
#        [0.20597154],
#        [0.20138115],
#        [0.1974996 ],
#        [0.19448358],
#        [0.19223818],
#        [0.19056442],
#        [0.18922803],
#        [0.18805663],
#        [0.18699765],
#        [0.18592015],
#        [0.18490118],
#        [0.18407558],
#        [0.18349406],
#        [0.18316606],
#        [0.18311307],
#        [0.18338743],
#        [0.18408169],
#        [0.18491584],
#        [0.18549222],
#        [0.18563226],
#        [0.18520635],
#        [0.18404245],
#        [0.18190005],
#        [0.1785078 ],
#        [0.17390871],
#        [0.16836452],
#        [0.16220924],
#        [0.1556797 ],
#        [0.14935297],
#        [0.14387545],
#        [0.13965529],
#        [0.13698587],
#        [0.13597485],
#        [0.13653898],
#        [0.13834432],
#        [0.14094651],
#        [0.1440515 ],
#        [0.14746211],
#        [0.15092826],
#        [0.15421471],
#        [0.15710515],
#        [0.1596969 ],
#        [0.16214365],
#        [0.16454892],
#        [0.16692728],
#        [0.16915247],
#        [0.17101082],
#        [0.17228454],
#        [0.17281696],
#        [0.17256024],
#        [0.17160839],
#        [0.1700482 ],
#        [0.16789694],
#        [0.16518673],
#        [0.16193168],
#        [0.15819865],
#        [0.15411338],
#        [0.14972478],
#        [0.14519784],
#        [0.14062202],
#        [0.13602203],
#        [0.1315369 ],
#        [0.12729637],
#        [0.12344511],
#        [0.12003127],
#        [0.11697365],
#        [0.11424276],
#        [0.1118435 ],
#        [0.10979505],
#        [0.1082463 ],
#        [0.10729207],
#        [0.10699694],
#        [0.10733767],
#        [0.1082204 ],
#        [0.10961649],
#        [0.11170793],
#        [0.11472706],
#        [0.1187209 ],
#        [0.12342696],
#        [0.12855275],
#        [0.13401362],
#        [0.13958177],
#        [0.14508094],
#        [0.15043753],
#        [0.15582605],
#        [0.16125965],
#        [0.16665453],
#        [0.17205042],
#        [0.17721628],
#        [0.18178858],
#        [0.18548784],
#        [0.18815117],
#        [0.18969862],
#        [0.19016884],
#        [0.1896473 ],
#        [0.1882139 ],
#        [0.18588004],
#        [0.18267417],
#        [0.17870492],
#        [0.17407027],
#        [0.16892979],
#        [0.16347368],
#        [0.1578895 ],
#        [0.15245096],
#        [0.14751159],
#        [0.14341879],
#        [0.14029846],
#        [0.13817987],
#        [0.1368989 ],
#        [0.13616823],
#        [0.13574092],
#        [0.1355512 ],
#        [0.13569392],
#        [0.13647404],
#        [0.13813484],
#        [0.14072138],
#        [0.14432648],
#        [0.14883363],
#        [0.15409851],
#        [0.15990159],
#        [0.16594699],
#        [0.17188618],
#        [0.17743629],
#        [0.1823963 ],
#        [0.18670116],
#        [0.19040701],
#        [0.19360875],
#        [0.19639193],
#        [0.19897975],
#        [0.2014873 ],
#        [0.20393422],
#        [0.20626184],
#        [0.20851743],
#        [0.21079676],
#        [0.21304858],
#        [0.21515024],
#        [0.21698472],
#        [0.21849695],
#        [0.21967106],
#        [0.22056133],
#        [0.22115242],
#        [0.22142842],
#        [0.2215402 ],
#        [0.22165807],
#        [0.22188596],
#        [0.22219472],
#        [0.22252892],
#        [0.22280124],
#        [0.2229846 ],
#        [0.22316477],
#        [0.22342497],
#        [0.22398299],
#        [0.22513878],
#        [0.22705284],
#        [0.22979431],
#        [0.23326315],
#        [0.23735239],
#        [0.24168584],
#        [0.24611454],
#        [0.25115323],
#        [0.25725913],
#        [0.2645124 ],
#        [0.27331918],
#        [0.28338522],
#        [0.2942388 ],
#        [0.3049205 ],
#        [0.3147046 ],
#        [0.3232899 ],
#        [0.33099306],
#        [0.33842057],
#        [0.34485036],
#        [0.34939253],
#        [0.35171682],
#        [0.3522994 ],
#        [0.3518713 ],
#        [0.35104772],
#        [0.35048285],
#        [0.35030976],
#        [0.35039985],
#        [0.35007566],
#        [0.3493531 ],
#        [0.3483027 ],
#        [0.3463994 ],
#        [0.34340307],
#        [0.33971453],
#        [0.3356167 ],
#        [0.33158568],
#        [0.32792276],
#        [0.32503372],
#        [0.32296532],
#        [0.3215225 ],
#        [0.32007754],
#        [0.31826654],
#        [0.31619206],
#        [0.3146714 ],
#        [0.31447518],
#        [0.315985  ],
#        [0.31913745],
#        [0.32336363],
#        [0.32752824],
#        [0.33062628],
#        [0.33246005],
#        [0.33333918],
#        [0.3345849 ],
#        [0.3374269 ],
#        [0.34296545],
#        [0.35129517],
#        [0.3617771 ],
#        [0.37320918],
#        [0.38440973],
#        [0.39429697],
#        [0.4026206 ],
#        [0.4094913 ],
#        [0.41483974],
#        [0.41857368],
#        [0.42077708],
#        [0.4220944 ],
#        [0.42275023],
#        [0.42257845],
#        [0.42182335],
#        [0.42024875],
#        [0.41793668],
#        [0.41535503],
#        [0.41381264],
#        [0.4135033 ],
#        [0.41422838],
#        [0.41586936],
#        [0.41862756],
#        [0.42278433],
#        [0.42830706],
#        [0.43491718],
#        [0.4421958 ],
#        [0.44955292],
#        [0.45650083],
#        [0.46279958],
#        [0.46840066],
#        [0.4731514 ],
#        [0.47708666],
#        [0.4804726 ],
#        [0.48349676],
#        [0.4863316 ],
#        [0.48906216],
#        [0.4912513 ],
#        [0.49190977],
#        [0.4900854 ],
#        [0.48575836],
#        [0.4788344 ],
#        [0.47022986],
#        [0.46166307],
#        [0.4541669 ],
#        [0.44877   ],
#        [0.4455075 ],
#        [0.44450325],
#        [0.4456217 ],
#        [0.44873932],
#        [0.45352238],
#        [0.459596  ],
#        [0.4667001 ],
#        [0.47444472],
#        [0.48221704],
#        [0.48961347],
#        [0.49641845],
#        [0.50235724],
#        [0.5071784 ],
#        [0.51050806],
#        [0.51227367],
#        [0.5128584 ],
#        [0.5108923 ],
#        [0.5038111 ],
#        [0.49036437],
#        [0.47246724],
#        [0.45247138],
#        [0.433043  ],
#        [0.4161961 ],
#        [0.40348357],
#        [0.3955056 ],
#        [0.39201206],
#        [0.39272738],
#        [0.39674062],
#        [0.4031528 ],
#        [0.41102841],
#        [0.4197113 ],
#        [0.42873782],
#        [0.43791455],
#        [0.44694492],
#        [0.45559728],
#        [0.46372485],
#        [0.47133476],
#        [0.47828013],
#        [0.48436445],
#        [0.48949233],
#        [0.49341816],
#        [0.495647  ],
#        [0.49565253],
#        [0.49275035],
#        [0.48732892],
#        [0.47995174],
#        [0.47307324],
#        [0.46791703],
#        [0.46462452],
#        [0.46286267],
#        [0.46218586],
#        [0.462076  ],
#        [0.46220303],
#        [0.4628002 ],
#        [0.46422672],
#        [0.46678644],
#        [0.47060704],
#        [0.47572958],
#        [0.48203856],
#        [0.48918977],
#        [0.49667388],
#        [0.503937  ],
#        [0.51039946],
#        [0.5157192 ],
#        [0.51950824],
#        [0.52152216],
#        [0.5220727 ],
#        [0.5219954 ],
#        [0.5220666 ],
#        [0.5228163 ],
#        [0.52452487],
#        [0.5272025 ],
#        [0.5305569 ],
#        [0.534433  ],
#        [0.5389834 ],
#        [0.54427123],
#        [0.55030096],
#        [0.55708337],
#        [0.56475216],
#        [0.57334167],
#        [0.5828047 ],
#        [0.5928068 ],
#        [0.6018132 ],
#        [0.6084318 ],
#        [0.61192465],
#        [0.61239994],
#        [0.6104902 ],
#        [0.6071663 ],
#        [0.603385  ],
#        [0.6001754 ],
#        [0.5981144 ],
#        [0.5971586 ],
#        [0.5970836 ],
#        [0.5972891 ],
#        [0.5969808 ],
#        [0.5956017 ],
#        [0.5931759 ],
#        [0.59016144],
#        [0.5870596 ],
#        [0.58354235],
#        [0.57935977],
#        [0.5740445 ],
#        [0.567783  ],
#        [0.5608152 ],
#        [0.5529368 ],
#        [0.54395425],
#        [0.5337983 ],
#        [0.5232188 ],
#        [0.51326525],
#        [0.5050904 ],
#        [0.4993911 ],
#        [0.49646997],
#        [0.49635586],
#        [0.4986406 ],
#        [0.5031892 ],
#        [0.50976247],
#        [0.5181773 ],
#        [0.5280586 ],
#        [0.5390986 ],
#        [0.550879  ],
#        [0.5629624 ],
#        [0.5749421 ],
#        [0.58646137],
#        [0.59758776],
#        [0.60837996],
#        [0.61885095],
#        [0.6285296 ],
#        [0.6371006 ],
#        [0.64462006],
#        [0.65143394],
#        [0.65781844],
#        [0.664183  ],
#        [0.67066526],
#        [0.6769719 ],
#        [0.68268275],
#        [0.68756026],
#        [0.6915852 ],
#        [0.69469094],
#        [0.6970596 ],
#        [0.6991089 ],
#        [0.7013073 ],
#        [0.7036909 ],
#        [0.7071085 ],
#        [0.71200794],
#        [0.7182154 ],
#        [0.725327  ],
#        [0.73306215],
#        [0.7411878 ],
#        [0.7495066 ],
#        [0.758     ],
#        [0.7665192 ],
#        [0.7748505 ],
#        [0.7826803 ],
#        [0.78977525],
#        [0.7960702 ],
#        [0.8017199 ],
#        [0.8069973 ],
#        [0.81222034],
#        [0.8176445 ],
#        [0.8234104 ],
#        [0.829417  ],
#        [0.8352536 ],
#        [0.8405701 ],
#        [0.8452709 ],
#        [0.8493433 ],
#        [0.85260475],
#        [0.8549057 ],
#        [0.85626876],
#        [0.85687137],
#        [0.85706043],
#        [0.85724187],
#        [0.8575845 ],
#        [0.8581259 ],
#        [0.8589362 ],
#        [0.8601284 ],
#        [0.8615978 ],
#        [0.86322975],
#        [0.8649628 ],
#        [0.86661494],
#        [0.8680643 ],
#        [0.8694073 ],
#        [0.8708149 ],
#        [0.8726423 ],
#        [0.8751421 ],
#        [0.8784027 ],
#        [0.8822261 ],
#        [0.8863063 ],
#        [0.89046276],
#        [0.8946152 ],
#        [0.89888823],
#        [0.90334964],
#        [0.90793097],
#        [0.9125868 ],
#        [0.9170371 ],
#        [0.92090774],
#        [0.92401946],
#        [0.92624784],
#        [0.92741513],
#        [0.9273211 ],
#        [0.925907  ],
#        [0.92349315],
#        [0.9205915 ],
#        [0.91725373],
#        [0.91307616],
#        [0.9077153 ],
#        [0.9012257 ],
#        [0.89398324],
#        [0.88652825],
#        [0.87934756],
#        [0.8725717 ],
#        [0.8657347 ],
#        [0.85831225],
#        [0.8500725 ],
#        [0.84125435],
#        [0.83239865],
#        [0.8239702 ],
#        [0.8164154 ],
#        [0.80980253],
#        [0.80406964],
#        [0.7992352 ],
#        [0.7955377 ],
#        [0.7932117 ],
#        [0.7922398 ],
#        [0.79224336],
#        [0.79288864],
#        [0.79394484],
#        [0.79512036],
#        [0.7960316 ],
#        [0.79632175],
#        [0.795931  ],
#        [0.794538  ],
#        [0.7918211 ],
#        [0.78775036],
#        [0.7820927 ],
#        [0.77454984],
#        [0.76510715],
#        [0.754254  ],
#        [0.7429395 ],
#        [0.7323259 ],
#        [0.7234312 ],
#        [0.71692276],
#        [0.71307385],
#        [0.7119007 ],
#        [0.71323586],
#        [0.716611  ],
#        [0.7214546 ],
#        [0.7271376 ],
#        [0.73313606],
#        [0.73913145],
#        [0.7450484 ],
#        [0.7509453 ],
#        [0.756768  ],
#        [0.7623836 ],
#        [0.7677418 ],
#        [0.7724929 ],
#        [0.77640593],
#        [0.7792163 ],
#        [0.7808075 ],
#        [0.7813387 ],
#        [0.78123164],
#        [0.78094804],
#        [0.78082514],
#        [0.78088415],
#        [0.7810601 ],
#        [0.78133786],
#        [0.78179073],
#        [0.7823051 ],
#        [0.78273034],
#        [0.7831452 ],
#        [0.7837776 ],
#        [0.78500164],
#        [0.7872889 ],
#        [0.79072917],
#        [0.7951293 ],
#        [0.8000357 ],
#        [0.80498636]], dtype=float32)

# %%
scaler.scale_
# Out:
# array([0.00916003])

# %%
scale = 1/scaler.scale_

# %%
y_predict = y_predict * scale

# %%
y = y * scale

# %%
plt.figure(figsize = (10,8))
plt.plot(y_predict,'r',label = 'Predicted Price')
plt.plot(y,'g',label = 'Original Price')
plt.xlabel('Time')
plt.ylabel('Price')
plt.legend()
plt.show()

# %%
model.save('Stock_Prediction_Model.keras')

# %%
model.save("Stock_prediction",save_format ='tf')
# Out:
# INFO:tensorflow:Assets written to: Stock_prediction\assets
# INFO:tensorflow:Assets written to: Stock_prediction\assets
